# %%
import pandas as pd
import os
import glob
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
raw_curry_stats = pd.read_csv('/Users/chen/cs-stuff/cs-personal/stephen-curry/data/raw/nba/Stephen_Curry_Stats_Init.csv')
